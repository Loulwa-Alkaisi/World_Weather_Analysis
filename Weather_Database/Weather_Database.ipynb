# %%
# Import the datetime module from the datetime library.
from datetime import datetime
import pandas as pd
from citipy import citipy
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs= np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add latitudes and longitudes into a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in city_data:
        city_data.append(city)
        

print("Beginning Data Retrieval     ")
print("-----------------------------")


record_count = 0
set_count = 0

city_name = []
city_lat = []
city_lng = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []
city_weather_description = []

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        city_lat.append(city_weather["coord"]["lat"])
        city_lng.append(city_weather["coord"]["lon"])
        city_max_temp.append(city_weather["main"]["temp_max"])
        city_humidity.append(city_weather["main"]["humidity"])
        city_clouds.append(city_weather["clouds"]["all"])
        city_wind.append(city_weather["wind"]["speed"])
        city_country.append(city_weather["sys"]["country"])
        city_date.append(datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S'))
        city_name.append(city)
        city_weather_description.append(city_weather["weather"][0]["description"])
    
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 0 | milkovo
# Processing Record 1 of Set 0 | rikitea
# Processing Record 2 of Set 0 | mataura
# Processing Record 3 of Set 0 | alekseyevka
# Processing Record 4 of Set 0 | sao miguel
# Processing Record 5 of Set 0 | punta arenas
# Processing Record 6 of Set 0 | kostomuksha
# Processing Record 7 of Set 0 | burnie
# Processing Record 8 of Set 0 | atuona
# Processing Record 9 of Set 0 | castro
# Processing Record 10 of Set 0 | provideniya
# Processing Record 11 of Set 0 | saint-leu
# Processing Record 12 of Set 0 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 0 | ballina
# Processing Record 14 of Set 0 | carmen
# Processing Record 15 of Set 0 | santa maria
# Processing Record 16 of Set 0 | sapao
# City not found. Skipping...
# Processing Record 17 of Set 0 | bambous virieux
# Processing Record 18 of Set 0 | saint-philippe
# Processing Record 19 of Set 0 | saint george
# Processing Record 20 of Set 0 | ushuaia
# Processing Record 21 of Set 0 | rio grande
# Processing Record 22 of Set 0 | ambon
# Processing Record 23 of Set 0 | hobart
# Processing Record 24 of Set 0 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 0 | lagoa
# Processing Record 26 of Set 0 | bluff
# Processing Record 27 of Set 0 | lebu
# Processing Record 28 of Set 0 | isangel
# Processing Record 29 of Set 0 | albany
# Processing Record 30 of Set 0 | upernavik
# Processing Record 31 of Set 0 | tasiilaq
# Processing Record 32 of Set 0 | sao filipe
# Processing Record 33 of Set 0 | langham
# Processing Record 34 of Set 0 | kushima
# Processing Record 35 of Set 0 | sudak
# Processing Record 36 of Set 0 | hermanus
# Processing Record 37 of Set 0 | tabuk
# Processing Record 38 of Set 0 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 0 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 0 | qaqortoq
# Processing Record 41 of Set 0 | mazara del vallo
# Processing Record 42 of Set 0 | riyadh
# Processing Record 43 of Set 0 | zemio
# Processing Record 44 of Set 0 | chuy
# Processing Record 45 of Set 0 | east london
# Processing Record 46 of Set 0 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 0 | busselton
# Processing Record 48 of Set 0 | vila franca do campo
# Processing Record 49 of Set 0 | chernyshevskiy
# Processing Record 0 of Set 1 | cap malheureux
# Processing Record 1 of Set 1 | shelburne
# Processing Record 2 of Set 1 | north bend
# Processing Record 3 of Set 1 | peachland
# Processing Record 4 of Set 1 | rawson
# Processing Record 5 of Set 1 | rioja
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | cidreira
# Processing Record 9 of Set 1 | aklavik
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | veere
# Processing Record 13 of Set 1 | kiomboi
# Processing Record 14 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 1 | chulman
# Processing Record 16 of Set 1 | korla
# Processing Record 17 of Set 1 | valreas
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 1 | adrar
# Processing Record 23 of Set 1 | port hardy
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | manhumirim
# Processing Record 26 of Set 1 | fort nelson
# Processing Record 27 of Set 1 | dunedin
# Processing Record 28 of Set 1 | cherskiy
# Processing Record 29 of Set 1 | camocim
# Processing Record 30 of Set 1 | launceston
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | van
# Processing Record 33 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | thinadhoo
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | broken hill
# Processing Record 39 of Set 1 | knysna
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | ahipara
# Processing Record 42 of Set 1 | dongdu
# Processing Record 43 of Set 1 | port macquarie
# Processing Record 44 of Set 1 | mezen
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | san patricio
# Processing Record 47 of Set 1 | locri
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | rawlins
# Processing Record 0 of Set 2 | dingle
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | tahe
# Processing Record 4 of Set 2 | balabac
# Processing Record 5 of Set 2 | los algarrobos
# Processing Record 6 of Set 2 | padang
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | ambanja
# Processing Record 9 of Set 2 | pathein
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | tokur
# Processing Record 13 of Set 2 | boa vista
# Processing Record 14 of Set 2 | hami
# Processing Record 15 of Set 2 | lavrentiya
# Processing Record 16 of Set 2 | santa marta de tormes
# Processing Record 17 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 2 | kholm
# Processing Record 19 of Set 2 | meulaboh
# Processing Record 20 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 2 | tessalit
# Processing Record 22 of Set 2 | tuatapere
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | sao geraldo do araguaia
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 2 | nanortalik
# Processing Record 28 of Set 2 | bilibino
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | umtata
# Processing Record 31 of Set 2 | malanje
# Processing Record 32 of Set 2 | santa cruz
# Processing Record 33 of Set 2 | guerrero negro
# Processing Record 34 of Set 2 | ubauro
# Processing Record 35 of Set 2 | codrington
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | paptalaya
# Processing Record 38 of Set 2 | bathsheba
# Processing Record 39 of Set 2 | emerald
# Processing Record 40 of Set 2 | palaia fokaia
# Processing Record 41 of Set 2 | karakol
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | nantucket
# Processing Record 44 of Set 2 | skjervoy
# Processing Record 45 of Set 2 | pergamino
# Processing Record 46 of Set 2 | marienburg
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | filingue
# Processing Record 49 of Set 2 | polyarnyy
# Processing Record 0 of Set 3 | puerto ayora
# Processing Record 1 of Set 3 | ipameri
# Processing Record 2 of Set 3 | yumen
# Processing Record 3 of Set 3 | jalaun
# Processing Record 4 of Set 3 | vostok
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | vardo
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | evensk
# Processing Record 10 of Set 3 | saint-pierre
# Processing Record 11 of Set 3 | axim
# Processing Record 12 of Set 3 | kosonsoy
# Processing Record 13 of Set 3 | olga
# Processing Record 14 of Set 3 | chamba
# Processing Record 15 of Set 3 | beringovskiy
# Processing Record 16 of Set 3 | nikolskoye
# Processing Record 17 of Set 3 | tirat karmel
# Processing Record 18 of Set 3 | birao
# Processing Record 19 of Set 3 | portland
# Processing Record 20 of Set 3 | gigmoto
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 3 | tura
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 3 | lata
# Processing Record 27 of Set 3 | taoudenni
# Processing Record 28 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | puerto escondido
# Processing Record 31 of Set 3 | novovarshavka
# Processing Record 32 of Set 3 | hauterive
# Processing Record 33 of Set 3 | aquiraz
# Processing Record 34 of Set 3 | ode
# Processing Record 35 of Set 3 | san quintin
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | bo rai
# Processing Record 38 of Set 3 | egvekinot
# Processing Record 39 of Set 3 | kenai
# Processing Record 40 of Set 3 | zaysan
# Processing Record 41 of Set 3 | sola
# Processing Record 42 of Set 3 | karratha
# Processing Record 43 of Set 3 | nyurba
# Processing Record 44 of Set 3 | marovoay
# Processing Record 45 of Set 3 | hilo
# Processing Record 46 of Set 3 | changli
# Processing Record 47 of Set 3 | syracuse
# Processing Record 48 of Set 3 | manadhoo
# Processing Record 49 of Set 3 | aksarka
# Processing Record 0 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 4 | matara
# Processing Record 2 of Set 4 | nuuk
# Processing Record 3 of Set 4 | esna
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | belaya gora
# Processing Record 6 of Set 4 | shitanjing
# Processing Record 7 of Set 4 | sakakah
# Processing Record 8 of Set 4 | saldanha
# Processing Record 9 of Set 4 | myitkyina
# Processing Record 10 of Set 4 | iqaluit
# Processing Record 11 of Set 4 | verkh-usugli
# Processing Record 12 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 4 | carutapera
# Processing Record 14 of Set 4 | namibe
# Processing Record 15 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 4 | fortuna
# Processing Record 17 of Set 4 | namatanai
# Processing Record 18 of Set 4 | ashqelon
# Processing Record 19 of Set 4 | ulladulla
# Processing Record 20 of Set 4 | nanlong
# Processing Record 21 of Set 4 | sayyan
# Processing Record 22 of Set 4 | constitucion
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | bajah
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | yatou
# Processing Record 27 of Set 4 | torbay
# Processing Record 28 of Set 4 | sabha
# Processing Record 29 of Set 4 | lewiston
# Processing Record 30 of Set 4 | bonthe
# Processing Record 31 of Set 4 | zyryanka
# Processing Record 32 of Set 4 | grindavik
# Processing Record 33 of Set 4 | flin flon
# Processing Record 34 of Set 4 | yar-sale
# Processing Record 35 of Set 4 | weligama
# Processing Record 36 of Set 4 | barrow
# Processing Record 37 of Set 4 | mahebourg
# Processing Record 38 of Set 4 | kuytun
# Processing Record 39 of Set 4 | jalu
# Processing Record 40 of Set 4 | mount gambier
# Processing Record 41 of Set 4 | luderitz
# Processing Record 42 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 4 | arraial do cabo
# Processing Record 44 of Set 4 | kondagaon
# Processing Record 45 of Set 4 | kandrian
# Processing Record 46 of Set 4 | maldonado
# Processing Record 47 of Set 4 | hamilton
# Processing Record 48 of Set 4 | hambantota
# Processing Record 49 of Set 4 | healesville
# Processing Record 0 of Set 5 | andenes
# Processing Record 1 of Set 5 | rio gallegos
# Processing Record 2 of Set 5 | harrisonville
# Processing Record 3 of Set 5 | tierralta
# Processing Record 4 of Set 5 | sabang
# Processing Record 5 of Set 5 | miedzychod
# Processing Record 6 of Set 5 | saint-augustin
# Processing Record 7 of Set 5 | nachingwea
# Processing Record 8 of Set 5 | kalianget
# Processing Record 9 of Set 5 | great bend
# Processing Record 10 of Set 5 | turukhansk
# Processing Record 11 of Set 5 | clyde river
# Processing Record 12 of Set 5 | chililabombwe
# Processing Record 13 of Set 5 | taksimo
# Processing Record 14 of Set 5 | pucallpa
# Processing Record 15 of Set 5 | brae
# Processing Record 16 of Set 5 | erzin
# Processing Record 17 of Set 5 | hit
# Processing Record 18 of Set 5 | yuancheng
# Processing Record 19 of Set 5 | zeya
# Processing Record 20 of Set 5 | huarmey
# Processing Record 21 of Set 5 | makakilo city
# Processing Record 22 of Set 5 | sur
# Processing Record 23 of Set 5 | kualakapuas
# Processing Record 24 of Set 5 | chupa
# Processing Record 25 of Set 5 | baykit
# Processing Record 26 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 5 | hofn
# Processing Record 28 of Set 5 | hasaki
# Processing Record 29 of Set 5 | devon
# Processing Record 30 of Set 5 | khorixas
# Processing Record 31 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 5 | baracoa
# Processing Record 33 of Set 5 | qui nhon
# Processing Record 34 of Set 5 | moindou
# Processing Record 35 of Set 5 | lashio
# Processing Record 36 of Set 5 | ponta delgada
# Processing Record 37 of Set 5 | tautira
# Processing Record 38 of Set 5 | san luis
# Processing Record 39 of Set 5 | gazanjyk
# Processing Record 40 of Set 5 | varna
# Processing Record 41 of Set 5 | labuhan
# Processing Record 42 of Set 5 | mecca
# Processing Record 43 of Set 5 | along
# Processing Record 44 of Set 5 | muroto
# Processing Record 45 of Set 5 | lumeje
# Processing Record 46 of Set 5 | sironj
# Processing Record 47 of Set 5 | avarua
# Processing Record 48 of Set 5 | spornoye
# Processing Record 49 of Set 5 | norman wells
# Processing Record 0 of Set 6 | takoradi
# Processing Record 1 of Set 6 | sumter
# Processing Record 2 of Set 6 | pangnirtung
# Processing Record 3 of Set 6 | kahului
# Processing Record 4 of Set 6 | talnakh
# Processing Record 5 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 6 | fort-shevchenko
# Processing Record 7 of Set 6 | daru
# Processing Record 8 of Set 6 | kibondo
# Processing Record 9 of Set 6 | aanekoski
# Processing Record 10 of Set 6 | port lincoln
# Processing Record 11 of Set 6 | klaksvik
# Processing Record 12 of Set 6 | huancavelica
# Processing Record 13 of Set 6 | kimparana
# Processing Record 14 of Set 6 | kosikha
# Processing Record 15 of Set 6 | deputatskiy
# Processing Record 16 of Set 6 | palmer
# Processing Record 17 of Set 6 | buchanan
# Processing Record 18 of Set 6 | bilma
# Processing Record 19 of Set 6 | ginir
# Processing Record 20 of Set 6 | shiyan
# Processing Record 21 of Set 6 | praia da vitoria
# Processing Record 22 of Set 6 | prabumulih
# Processing Record 23 of Set 6 | havelock
# Processing Record 24 of Set 6 | arman
# Processing Record 25 of Set 6 | kodiak
# Processing Record 26 of Set 6 | pevek
# Processing Record 27 of Set 6 | manta
# Processing Record 28 of Set 6 | pailon
# Processing Record 29 of Set 6 | nouakchott
# Processing Record 30 of Set 6 | itamarandiba
# Processing Record 31 of Set 6 | airai
# Processing Record 32 of Set 6 | narsaq
# Processing Record 33 of Set 6 | whyalla
# Processing Record 34 of Set 6 | husavik
# Processing Record 35 of Set 6 | usinsk
# Processing Record 36 of Set 6 | ancud
# Processing Record 37 of Set 6 | tadine
# Processing Record 38 of Set 6 | saint anthony
# Processing Record 39 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 6 | kautokeino
# Processing Record 41 of Set 6 | tucupita
# Processing Record 42 of Set 6 | ornskoldsvik
# Processing Record 43 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 6 | emba
# Processing Record 45 of Set 6 | hwange
# Processing Record 46 of Set 6 | shirokiy
# Processing Record 47 of Set 6 | morant bay
# Processing Record 48 of Set 6 | esperance
# Processing Record 49 of Set 6 | marsh harbour
# Processing Record 0 of Set 7 | acarau
# Processing Record 1 of Set 7 | mikuni
# Processing Record 2 of Set 7 | okahandja
# Processing Record 3 of Set 7 | port augusta
# Processing Record 4 of Set 7 | imbituba
# Processing Record 5 of Set 7 | poiana lacului
# Processing Record 6 of Set 7 | ixtapa
# Processing Record 7 of Set 7 | hvide sande
# Processing Record 8 of Set 7 | bhabua
# Processing Record 9 of Set 7 | havre-saint-pierre
# Processing Record 10 of Set 7 | thompson
# Processing Record 11 of Set 7 | nabire
# Processing Record 12 of Set 7 | almaznyy
# Processing Record 13 of Set 7 | kruisfontein
# Processing Record 14 of Set 7 | abalak
# Processing Record 15 of Set 7 | port hawkesbury
# Processing Record 16 of Set 7 | verkhnevilyuysk
# Processing Record 17 of Set 7 | santiago del estero
# Processing Record 18 of Set 7 | cortes
# Processing Record 19 of Set 7 | avera
# Processing Record 20 of Set 7 | vestmanna
# Processing Record 21 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 22 of Set 7 | vestmannaeyjar
# Processing Record 23 of Set 7 | dekar
# Processing Record 24 of Set 7 | newport
# Processing Record 25 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 7 | tazovskiy
# Processing Record 27 of Set 7 | devils lake
# Processing Record 28 of Set 7 | sinnamary
# Processing Record 29 of Set 7 | celestun
# Processing Record 30 of Set 7 | kaeo
# Processing Record 31 of Set 7 | forquilhinha
# Processing Record 32 of Set 7 | coihaique
# Processing Record 33 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 7 | awbari
# Processing Record 35 of Set 7 | nouadhibou
# Processing Record 36 of Set 7 | mudgee
# Processing Record 37 of Set 7 | high level
# Processing Record 38 of Set 7 | faya
# Processing Record 39 of Set 7 | kilindoni
# Processing Record 40 of Set 7 | acapulco
# Processing Record 41 of Set 7 | naryan-mar
# Processing Record 42 of Set 7 | nemuro
# Processing Record 43 of Set 7 | corrales
# Processing Record 44 of Set 7 | gresham
# Processing Record 45 of Set 7 | asyut
# Processing Record 46 of Set 7 | bocas del toro
# Processing Record 47 of Set 7 | sarankhola
# Processing Record 48 of Set 7 | kisii
# Processing Record 49 of Set 7 | tromso
# Processing Record 0 of Set 8 | poum
# Processing Record 1 of Set 8 | alta floresta
# Processing Record 2 of Set 8 | northam
# Processing Record 3 of Set 8 | san rafael
# Processing Record 4 of Set 8 | la ronge
# Processing Record 5 of Set 8 | bacalar
# Processing Record 6 of Set 8 | salalah
# Processing Record 7 of Set 8 | tiksi
# Processing Record 8 of Set 8 | kichera
# Processing Record 9 of Set 8 | quixeramobim
# Processing Record 10 of Set 8 | xining
# Processing Record 11 of Set 8 | zhigansk
# Processing Record 12 of Set 8 | mpulungu
# Processing Record 13 of Set 8 | arinos
# Processing Record 14 of Set 8 | esso
# Processing Record 15 of Set 8 | college
# Processing Record 16 of Set 8 | zverinogolovskoye
# Processing Record 17 of Set 8 | lao cai
# Processing Record 18 of Set 8 | dudinka
# Processing Record 19 of Set 8 | vanimo
# Processing Record 20 of Set 8 | bandarbeyla
# Processing Record 21 of Set 8 | nalut
# Processing Record 22 of Set 8 | kollam
# Processing Record 23 of Set 8 | kiunga
# Processing Record 24 of Set 8 | port hedland
# Processing Record 25 of Set 8 | kattivakkam
# Processing Record 26 of Set 8 | guarapari
# Processing Record 27 of Set 8 | timmins
# Processing Record 28 of Set 8 | fort dodge
# Processing Record 29 of Set 8 | ilulissat
# Processing Record 30 of Set 8 | puro
# Processing Record 31 of Set 8 | blytheville
# Processing Record 32 of Set 8 | chegdomyn
# Processing Record 33 of Set 8 | robertsport
# Processing Record 34 of Set 8 | tual
# Processing Record 35 of Set 8 | andros
# Processing Record 36 of Set 8 | general pico
# Processing Record 37 of Set 8 | malveira
# Processing Record 38 of Set 8 | hanyang
# Processing Record 39 of Set 8 | santa rosa
# Processing Record 40 of Set 8 | caravelas
# Processing Record 41 of Set 8 | quatre cocos
# Processing Record 42 of Set 8 | tigil
# Processing Record 43 of Set 8 | cayenne
# Processing Record 44 of Set 8 | swellendam
# Processing Record 45 of Set 8 | vaitape
# Processing Record 46 of Set 8 | varkkallai
# Processing Record 47 of Set 8 | tucuma
# Processing Record 48 of Set 8 | buala
# Processing Record 49 of Set 8 | edd
# Processing Record 0 of Set 9 | porto novo
# Processing Record 1 of Set 9 | le port
# Processing Record 2 of Set 9 | sorong
# Processing Record 3 of Set 9 | udachnyy
# Processing Record 4 of Set 9 | urubamba
# Processing Record 5 of Set 9 | marzuq
# Processing Record 6 of Set 9 | sarwar
# Processing Record 7 of Set 9 | puerto narino
# Processing Record 8 of Set 9 | campo maior
# Processing Record 9 of Set 9 | barvinkove
# Processing Record 10 of Set 9 | conway
# Processing Record 11 of Set 9 | saint-joseph
# Processing Record 12 of Set 9 | albion
# Processing Record 13 of Set 9 | miramar
# Processing Record 14 of Set 9 | ankang
# Processing Record 15 of Set 9 | muzhi
# Processing Record 16 of Set 9 | kloulklubed
# Processing Record 17 of Set 9 | santa cruz de la palma
# Processing Record 18 of Set 9 | pacific grove
# Processing Record 19 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 20 of Set 9 | oudtshoorn
# Processing Record 21 of Set 9 | jharsuguda
# Processing Record 22 of Set 9 | metro
# Processing Record 23 of Set 9 | santander
# Processing Record 24 of Set 9 | inhambane
# Processing Record 25 of Set 9 | maragogi
# Processing Record 26 of Set 9 | armidale
# Processing Record 27 of Set 9 | porto walter
# Processing Record 28 of Set 9 | oranjemund
# Processing Record 29 of Set 9 | hualmay
# Processing Record 30 of Set 9 | torrelavega
# Processing Record 31 of Set 9 | ajmer
# Processing Record 32 of Set 9 | idukki
# Processing Record 33 of Set 9 | ntoum
# Processing Record 34 of Set 9 | prince rupert
# Processing Record 35 of Set 9 | ashland
# Processing Record 36 of Set 9 | goroka
# Processing Record 37 of Set 9 | wukari
# Processing Record 38 of Set 9 | oussouye
# Processing Record 39 of Set 9 | krasnousolskiy
# City not found. Skipping...
# Processing Record 40 of Set 9 | sistranda
# Processing Record 41 of Set 9 | pisco
# Processing Record 42 of Set 9 | sicuani
# Processing Record 43 of Set 9 | ambulu
# Processing Record 44 of Set 9 | rundu
# Processing Record 45 of Set 9 | bam
# Processing Record 46 of Set 9 | curup
# Processing Record 47 of Set 9 | te anau
# Processing Record 48 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 49 of Set 9 | palladam
# Processing Record 0 of Set 10 | eganville
# Processing Record 1 of Set 10 | hengshui
# Processing Record 2 of Set 10 | beisfjord
# Processing Record 3 of Set 10 | lithgow
# Processing Record 4 of Set 10 | minas
# Processing Record 5 of Set 10 | kaitangata
# Processing Record 6 of Set 10 | fukue
# Processing Record 7 of Set 10 | ghanzi
# Processing Record 8 of Set 10 | arvika
# Processing Record 9 of Set 10 | lorengau
# Processing Record 10 of Set 10 | carmelo
# Processing Record 11 of Set 10 | yarkovo
# Processing Record 12 of Set 10 | gat
# Processing Record 13 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 10 | mahon
# Processing Record 15 of Set 10 | salym
# Processing Record 16 of Set 10 | barranca
# Processing Record 17 of Set 10 | rantepao
# Processing Record 18 of Set 10 | boueni
# Processing Record 19 of Set 10 | luanda
# Processing Record 20 of Set 10 | vila velha
# Processing Record 21 of Set 10 | krasnoselkup
# Processing Record 22 of Set 10 | shahe
# Processing Record 23 of Set 10 | cairns
# Processing Record 24 of Set 10 | kabinda
# Processing Record 25 of Set 10 | berlevag
# Processing Record 26 of Set 10 | nianzishan
# Processing Record 27 of Set 10 | belmonte
# Processing Record 28 of Set 10 | ustyuzhna
# Processing Record 29 of Set 10 | candolim
# Processing Record 30 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 10 | boende
# Processing Record 32 of Set 10 | beyla
# Processing Record 33 of Set 10 | kieta
# Processing Record 34 of Set 10 | springbok
# Processing Record 35 of Set 10 | slave lake
# Processing Record 36 of Set 10 | roald
# Processing Record 37 of Set 10 | leninogorsk
# Processing Record 38 of Set 10 | lubango
# Processing Record 39 of Set 10 | gayeri
# Processing Record 40 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 10 | bacolod
# Processing Record 42 of Set 10 | goba
# Processing Record 43 of Set 10 | verkhoyansk
# Processing Record 44 of Set 10 | athabasca
# Processing Record 45 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 46 of Set 10 | stavern
# Processing Record 47 of Set 10 | rincon
# Processing Record 48 of Set 10 | broome
# Processing Record 49 of Set 10 | medea
# Processing Record 0 of Set 11 | honiara
# Processing Record 1 of Set 11 | arequipa
# Processing Record 2 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 11 | victor harbor
# Processing Record 4 of Set 11 | saint-denis
# Processing Record 5 of Set 11 | aykhal
# Processing Record 6 of Set 11 | nhulunbuy
# Processing Record 7 of Set 11 | birin
# Processing Record 8 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 11 | bougouni
# Processing Record 10 of Set 11 | ranong
# Processing Record 11 of Set 11 | de-kastri
# Processing Record 12 of Set 11 | cristalina
# Processing Record 13 of Set 11 | yaan
# Processing Record 14 of Set 11 | balotra
# Processing Record 15 of Set 11 | bosaso
# Processing Record 16 of Set 11 | gabu
# Processing Record 17 of Set 11 | ilovlya
# Processing Record 18 of Set 11 | biak
# Processing Record 19 of Set 11 | alofi
# Processing Record 20 of Set 11 | srednekolymsk
# Processing Record 21 of Set 11 | falam
# Processing Record 22 of Set 11 | inta
# Processing Record 23 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 11 | gualaquiza
# Processing Record 25 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 26 of Set 11 | hay river
# Processing Record 27 of Set 11 | toamua
# City not found. Skipping...
# Processing Record 28 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 11 | paysandu
# Processing Record 30 of Set 11 | rypefjord
# Processing Record 31 of Set 11 | lozovik
# Processing Record 32 of Set 11 | lahan
# Processing Record 33 of Set 11 | shurugwi
# Processing Record 34 of Set 11 | pedernales
# Processing Record 35 of Set 11 | iacu
# Processing Record 36 of Set 11 | walvis bay
# Processing Record 37 of Set 11 | lagunas
# Processing Record 38 of Set 11 | urumqi
# Processing Record 39 of Set 11 | north charleston
# Processing Record 40 of Set 11 | ada
# Processing Record 41 of Set 11 | olavarria
# Processing Record 42 of Set 11 | baykalovo
# Processing Record 43 of Set 11 | kinablangan
# Processing Record 44 of Set 11 | pasighat
# Processing Record 45 of Set 11 | beloha
# Processing Record 46 of Set 11 | ende
# Processing Record 47 of Set 11 | czersk
# Processing Record 48 of Set 11 | margate
# Processing Record 49 of Set 11 | puerto carreno
# Processing Record 0 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 1 of Set 12 | kupang
# Processing Record 2 of Set 12 | ambovombe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 603

# %%
city_data = {"City": city_name,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date,
            "Current Description": city_weather_description}

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       milkovo  54.7167  158.6167     43.48        88         100
# 1       rikitea -23.1203 -134.9692     73.62        63          83
# 2       mataura -46.1927  168.8643     47.48        85         100
# 3   alekseyevka  50.6309   38.6903     51.03        62          78
# 4    sao miguel  -5.4667  -35.3667     81.37        72           4
# 5  punta arenas -53.1500  -70.9167     44.71        57           0
# 6   kostomuksha  64.5710   30.5767     43.68        87          88
# 7        burnie -41.0667  145.9167     55.92        96         100
# 8        atuona  -9.8000 -139.0333     77.70        75          13
# 9        castro -24.7911  -50.0119     63.72        99         100
#
#    Wind Speed Country                 Date   Current Description
# 0       12.64      RU  2021-10-03 21:25:42       overcast clouds
# 1       17.25      PF  2021-10-03 21:25:42         broken clouds
# 2        8.16      NZ  2021-10-03 21:25:42       overcast clouds
# 3        5.70      RU  2021-10-03 21:25:43         broken clouds
# 4       15.77      BR  2021-10-03 21:25:43             clear sky
# 5       34.52      CL  2021-10-03 21:20:06             clear sky
# 6       10.31      RU  2021-10-03 21:25:44       overcast clouds
# 7       11.72      AU  2021-10-03 21:25:44            light rain
# 8       17.78      PF  2021-10-03 21:20:37            few clouds
# 9        4.59      BR  2021-10-03 21:20:55  heavy intensity rain

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0       milkovo      RU  2021-10-03 21:25:42  54.7167  158.6167     43.48
# 1       rikitea      PF  2021-10-03 21:25:42 -23.1203 -134.9692     73.62
# 2       mataura      NZ  2021-10-03 21:25:42 -46.1927  168.8643     47.48
# 3   alekseyevka      RU  2021-10-03 21:25:43  50.6309   38.6903     51.03
# 4    sao miguel      BR  2021-10-03 21:25:43  -5.4667  -35.3667     81.37
# 5  punta arenas      CL  2021-10-03 21:20:06 -53.1500  -70.9167     44.71
# 6   kostomuksha      RU  2021-10-03 21:25:44  64.5710   30.5767     43.68
# 7        burnie      AU  2021-10-03 21:25:44 -41.0667  145.9167     55.92
# 8        atuona      PF  2021-10-03 21:20:37  -9.8000 -139.0333     77.70
# 9        castro      BR  2021-10-03 21:20:55 -24.7911  -50.0119     63.72
#
#    Humidity  Cloudiness  Wind Speed   Current Description
# 0        88         100       12.64       overcast clouds
# 1        63          83       17.25         broken clouds
# 2        85         100        8.16       overcast clouds
# 3        62          78        5.70         broken clouds
# 4        72           4       15.77             clear sky
# 5        57           0       34.52             clear sky
# 6        87          88       10.31       overcast clouds
# 7        96         100       11.72            light rain
# 8        75          13       17.78            few clouds
# 9        99         100        4.59  heavy intensity rain

# %%
output_data_file = "WeatherPy_database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
